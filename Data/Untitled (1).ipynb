# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# URL
url = "https://en.wikipedia.org/wiki/1936_United_States_presidential_election"

# Request
response = requests.get(url)
soup = BeautifulSoup(response.content)

response.status_code
# Out:
# 200

# %%
# Get only target table
target_table = None
for table in soup.find_all("table", class_="wikitable"):
    caption = table.find("caption")
    if caption and "Electoral results" in caption.text: #from inspect on site
        target_table = table
        

# Read table into pandas df
df_1_actual_results = pd.read_html(str(target_table))[0]


df_1_actual_results.head(25)
# Out:
# /var/folders/t1/nb2p0ppn0t1fldv4wgzvfrtw0000gn/T/ipykernel_21263/4191124071.py:10: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_1_actual_results = pd.read_html(str(target_table))[0]
#               Presidential candidate            Party     Home state  \
#               Presidential candidate            Party     Home state
# 0  Franklin D. Roosevelt (incumbent)       Democratic       New York
# 1                         Alf Landon       Republican         Kansas
# 2                      William Lemke            Union   North Dakota
# 3                      Norman Thomas        Socialist       New York
# 4                       Earl Browder        Communist         Kansas
# 5                    D. Leigh Colvin      Prohibition       New York
# 6                      John W. Aiken  Socialist Labor    Connecticut
# 7                              Other            Other          Other
# 8                              Total            Total          Total
# 9                      Needed to win    Needed to win  Needed to win
#
#     Popular vote                Electoral vote                   Running mate  \
#            Count     Percentage Electoral vote    Vice-presidential candidate
# 0       27752648         60.80%            523  John Nance Garner (incumbent)
# 1       16681862         36.54%              8                     Frank Knox
# 2         892378          1.95%              0              Thomas C. O'Brien
# 3         187910          0.41%              0               George A. Nelson
# 4          79315          0.17%              0                  James W. Ford
# 5          37646          0.08%              0               Claude A. Watson
# 6          12799          0.03%              0               Emil F. Teichert
# 7           3141          0.00%              —                          Other
# 8       45647699           100%            531                            NaN
# 9  Needed to win  Needed to win            266                            NaN
#
#
#       Home state Electoral vote
# 0          Texas            523
# 1       Illinois              8
# 2  Massachusetts              0
# 3      Wisconsin              0
# 4       New York              0
# 5     California              0
# 6       New York              0
# 7          Other              —
# 8            NaN            531
# 9            NaN            266

# %%
# Get rid of multi index column headers

# Flatten multi index column headers
df_1_actual_results.columns = ['_'.join(col).strip().replace(" ", "_").lower() for col in df_1_actual_results.columns.values]

df_1_actual_results.head()
# Out:
#   presidential_candidate_presidential_candidate party_party  \
# 0             Franklin D. Roosevelt (incumbent)  Democratic
# 1                                    Alf Landon  Republican
# 2                                 William Lemke       Union
# 3                                 Norman Thomas   Socialist
# 4                                  Earl Browder   Communist
#
#   home_state_home_state popular_vote_count popular_vote_percentage  \
# 0              New York           27752648                  60.80%
# 1                Kansas           16681862                  36.54%
# 2          North Dakota             892378                   1.95%
# 3              New York             187910                   0.41%
# 4                Kansas              79315                   0.17%
#
#   electoral_vote_electoral_vote running_mate_vice-presidential_candidate  \
# 0                           523            John Nance Garner (incumbent)
# 1                             8                               Frank Knox
# 2                             0                        Thomas C. O'Brien
# 3                             0                         George A. Nelson
# 4                             0                            James W. Ford
#
#   running_mate_home_state running_mate_electoral_vote
# 0                   Texas                         523
# 1                Illinois                           8
# 2           Massachusetts                           0
# 3               Wisconsin                           0
# 4                New York                           0

# %%
# Add year column for year 1936 for all rows in df

df_1_actual_results['year'] = 1936

df_1_actual_results.head(25)
# Out:
#   presidential_candidate_presidential_candidate      party_party  \
# 0             Franklin D. Roosevelt (incumbent)       Democratic
# 1                                    Alf Landon       Republican
# 2                                 William Lemke            Union
# 3                                 Norman Thomas        Socialist
# 4                                  Earl Browder        Communist
# 5                               D. Leigh Colvin      Prohibition
# 6                                 John W. Aiken  Socialist Labor
# 7                                         Other            Other
# 8                                         Total            Total
# 9                                 Needed to win    Needed to win
#
#   home_state_home_state popular_vote_count popular_vote_percentage  \
# 0              New York           27752648                  60.80%
# 1                Kansas           16681862                  36.54%
# 2          North Dakota             892378                   1.95%
# 3              New York             187910                   0.41%
# 4                Kansas              79315                   0.17%
# 5              New York              37646                   0.08%
# 6           Connecticut              12799                   0.03%
# 7                 Other               3141                   0.00%
# 8                 Total           45647699                    100%
# 9         Needed to win      Needed to win           Needed to win
#
#   electoral_vote_electoral_vote running_mate_vice-presidential_candidate  \
# 0                           523            John Nance Garner (incumbent)
# 1                             8                               Frank Knox
# 2                             0                        Thomas C. O'Brien
# 3                             0                         George A. Nelson
# 4                             0                            James W. Ford
# 5                             0                         Claude A. Watson
# 6                             0                         Emil F. Teichert
# 7                             —                                    Other
# 8                           531                                      NaN
# 9                           266                                      NaN
#
#   running_mate_home_state running_mate_electoral_vote  year
# 0                   Texas                         523  1936
# 1                Illinois                           8  1936
# 2           Massachusetts                           0  1936
# 3               Wisconsin                           0  1936
# 4                New York                           0  1936
# 5              California                           0  1936
# 6                New York                           0  1936
# 7                   Other                           —  1936
# 8                     NaN                         531  1936
# 9                     NaN                         266  1936

# %%
df_1_actual_results.columns
# Out:
# Index(['presidential_candidate_presidential_candidate', 'party_party',
#        'home_state_home_state', 'popular_vote_count',
#        'popular_vote_percentage', 'electoral_vote_electoral_vote',
#        'running_mate_vice-presidential_candidate', 'running_mate_home_state',
#        'running_mate_electoral_vote', 'year'],
#       dtype='object')

# %%
# drop presidential_candidate_presidential_candidate, home_state_home_state, running_mate_vice-presidential_candidate, 
#running_mate_home_state, running_mate_electoral_vote

columns_to_drop = [
    'presidential_candidate_presidential_candidate',
    'home_state_home_state',
    'running_mate_vice-presidential_candidate',
    'running_mate_home_state',
    'running_mate_electoral_vote'
]

df_1_actual_results = df_1_actual_results.drop(columns=columns_to_drop)


df_1_actual_results.head(25)
# Out:
#        party_party popular_vote_count popular_vote_percentage  \
# 0       Democratic           27752648                  60.80%
# 1       Republican           16681862                  36.54%
# 2            Union             892378                   1.95%
# 3        Socialist             187910                   0.41%
# 4        Communist              79315                   0.17%
# 5      Prohibition              37646                   0.08%
# 6  Socialist Labor              12799                   0.03%
# 7            Other               3141                   0.00%
# 8            Total           45647699                    100%
# 9    Needed to win      Needed to win           Needed to win
#
#   electoral_vote_electoral_vote  year
# 0                           523  1936
# 1                             8  1936
# 2                             0  1936
# 3                             0  1936
# 4                             0  1936
# 5                             0  1936
# 6                             0  1936
# 7                             —  1936
# 8                           531  1936
# 9                           266  1936

# %%
# drop rows 2-7 (Union to Other)
df_1_actual_results = df_1_actual_results.drop(index=range(2, 8))

# Reset index
df_1_actual_results = df_1_actual_results.reset_index(drop=True)

df_1_actual_results.head(25)
# Out:
#      party_party popular_vote_count popular_vote_percentage  \
# 0     Democratic           27752648                  60.80%
# 1     Republican           16681862                  36.54%
# 2          Total           45647699                    100%
# 3  Needed to win      Needed to win           Needed to win
#
#   electoral_vote_electoral_vote  year
# 0                           523  1936
# 1                             8  1936
# 2                           531  1936
# 3                           266  1936

# %%
# Rename party_party to party
# Rename electoral_vote_electoral_vote to electoral_vote

df_1_actual_results = df_1_actual_results.rename(columns={
    'party_party': 'party',
    'electoral_vote_electoral_vote': 'electoral_vote'
})

df_1_actual_results.head()
# Out:
#            party popular_vote_count popular_vote_percentage electoral_vote  \
# 0     Democratic           27752648                  60.80%            523
# 1     Republican           16681862                  36.54%              8
# 2          Total           45647699                    100%            531
# 3  Needed to win      Needed to win           Needed to win            266
#
#    year
# 0  1936
# 1  1936
# 2  1936
# 3  1936

# %%
df_1_actual_results.columns
# Out:
# Index(['party', 'popular_vote_count', 'popular_vote_percentage',
#        'electoral_vote', 'year'],
#       dtype='object')

# %%
df_filtered = df_1_actual_results[df_1_actual_results['party'] != 'Needed to win']

df_filtered.head()
# Out:
#         party popular_vote_count popular_vote_percentage electoral_vote  year
# 0  Democratic           27752648                  60.80%            523  1936
# 1  Republican           16681862                  36.54%              8  1936
# 2       Total           45647699                    100%            531  1936

# %%
# Pivot
df_wide = df_filtered.set_index('party').T

df_wide.head()
# Out:
# party                   Democratic Republican     Total
# popular_vote_count        27752648   16681862  45647699
# popular_vote_percentage     60.80%     36.54%      100%
# electoral_vote                 523          8       531
# year                          1936       1936      1936

# %%
# Rename Total column to match 1936 table
df_wide = df_wide.rename(columns={'Total': 'Total_Popular_Vote'})

df_wide.head()
# Out:
# party                   Democratic Republican Total_Popular_Vote
# popular_vote_count        27752648   16681862           45647699
# popular_vote_percentage     60.80%     36.54%               100%
# electoral_vote                 523          8                531
# year                          1936       1936               1936

# %%
# Putting everything we learned together and seeing if it works
# Match to 1936 table for easy merge

rep_electoral = int(df_wide.loc['electoral_vote', 'Republican'])
dem_electoral = int(df_wide.loc['electoral_vote', 'Democratic'])
total_electoral = int(df_wide.loc['electoral_vote', 'Total_Popular_Vote'])

rep_popular = int(df_wide.loc['popular_vote_count', 'Republican'])
dem_popular = int(df_wide.loc['popular_vote_count', 'Democratic'])
total_popular = int(df_wide.loc['popular_vote_count', 'Total_Popular_Vote'])

# turn into floats
rep_popular_pct = float(df_wide.loc['popular_vote_percentage', 'Republican'].replace('%',''))
dem_popular_pct = float(df_wide.loc['popular_vote_percentage', 'Democratic'].replace('%',''))

# %%
# Calculate Electoral Percentages and Leading Margins

rep_electoral_pct = round(rep_electoral / total_electoral * 100, 2)
dem_electoral_pct = round(dem_electoral / total_electoral * 100, 2)

electoral_margin = abs(dem_electoral_pct - rep_electoral_pct)
popular_margin = abs(dem_popular_pct - rep_popular_pct)

# %%
final_df = pd.DataFrame({
    'Republican_Electoral':[rep_electoral],
    
    'Democrat_Electoral':[dem_electoral],
    
    'Republican_Popular':[rep_popular],
    
    'Democrat_Popular':[dem_popular],
    
    'Total_Popular_Vote':[total_popular],

    'Republican_Electoral_pct':[rep_electoral_pct],
    
    'Democrat_Electoral_pct':[dem_electoral_pct],
    
    'Republican_Popular_pct':[rep_popular_pct],
    
    'Democrat_Popular_pct':[dem_popular_pct],

    'Electoral_Leading_Margin':[electoral_margin],
    
    'Popular_Leading_Margin':[popular_margin]
})

final_df.head()
# Out:
#    Republican_Electoral  Democrat_Electoral  Republican_Popular  \
# 0                     8                 523            16681862
#
#    Democrat_Popular  Total_Popular_Vote  Republican_Electoral_pct  \
# 0          27752648            45647699                      1.51
#
#    Democrat_Electoral_pct  Republican_Popular_pct  Democrat_Popular_pct  \
# 0                   98.49                   36.54                  60.8
#
#    Electoral_Leading_Margin  Popular_Leading_Margin
# 0                     96.98                   24.26

# %%
final_df.to_csv('1936_Actual_Election_Results.csv', index=False)

# %%
# Combine both datasets

poll_df = pd.read_csv("../Historical_Poll_Data/1936_Opinion_Polling_Data.csv")
actual_df = pd.read_csv("1936_Actual_Election_Results.csv")

# %%
# Confirm shapes 
poll_df.shape
actual_df.shape
# Out:
# (1, 11)

# %%
# Combine horizontally where axis=1
combined_df = pd.concat([poll_df, actual_df], axis=1)

combined_df.head(25)
# Out:
#    year  Democratic  Republican  Poll_Leading_Margin  Poll_Leader  \
# 0  1936        49.0        45.0                  4.0            0
# 1  1936        49.0        45.0                  4.0            0
# 2  1936        49.0        45.0                  4.0            0
# 3  1936        49.0        44.0                  5.0            0
# 4  1936        49.0        45.0                  4.0            0
# 5  1936        50.0        44.0                  6.0            0
# 6  1936        51.0        44.0                  7.0            0
# 7  1936        51.0        44.0                  7.0            0
# 8  1936        56.0        44.0                 12.0            0
#
#    Republican_Electoral  Democrat_Electoral  Republican_Popular  \
# 0                   8.0               523.0          16681862.0
# 1                   NaN                 NaN                 NaN
# 2                   NaN                 NaN                 NaN
# 3                   NaN                 NaN                 NaN
# 4                   NaN                 NaN                 NaN
# 5                   NaN                 NaN                 NaN
# 6                   NaN                 NaN                 NaN
# 7                   NaN                 NaN                 NaN
# 8                   NaN                 NaN                 NaN
#
#    Democrat_Popular  Total_Popular_Vote  Republican_Electoral_pct  \
# 0        27752648.0          45647699.0                      1.51
# 1               NaN                 NaN                       NaN
# 2               NaN                 NaN                       NaN
# 3               NaN                 NaN                       NaN
# 4               NaN                 NaN                       NaN
# 5               NaN                 NaN                       NaN
# 6               NaN                 NaN                       NaN
# 7               NaN                 NaN                       NaN
# 8               NaN                 NaN                       NaN
#
#    Democrat_Electoral_pct  Republican_Popular_pct  Democrat_Popular_pct  \
# 0                   98.49                   36.54                  60.8
# 1                     NaN                     NaN                   NaN
# 2                     NaN                     NaN                   NaN
# 3                     NaN                     NaN                   NaN
# 4                     NaN                     NaN                   NaN
# 5                     NaN                     NaN                   NaN
# 6                     NaN                     NaN                   NaN
# 7                     NaN                     NaN                   NaN
# 8                     NaN                     NaN                   NaN
#
#    Electoral_Leading_Margin  Popular_Leading_Margin
# 0                     96.98                   24.26
# 1                       NaN                     NaN
# 2                       NaN                     NaN
# 3                       NaN                     NaN
# 4                       NaN                     NaN
# 5                       NaN                     NaN
# 6                       NaN                     NaN
# 7                       NaN                     NaN
# 8                       NaN                     NaN

# %%
# Fill all NaN from Actual Election Results with value for all rows
# For example, the whole of Republican_Electoral column should be 8.0
actual_cols = [
    'Republican_Electoral','Democrat_Electoral',
    'Republican_Popular', 'Democrat_Popular',
    'Total_Popular_Vote', 'Republican_Electoral_pct',
    'Democrat_Electoral_pct', 'Republican_Popular_pct',
    'Democrat_Popular_pct', 'Electoral_Leading_Margin',
    'Popular_Leading_Margin'
]

# %%
for col in actual_cols:
    combined_df[col] = combined_df[col].iloc[0]

combined_df.head(25)
# Out:
#    year  Democratic  Republican  Poll_Leading_Margin  Poll_Leader  \
# 0  1936        49.0        45.0                  4.0            0
# 1  1936        49.0        45.0                  4.0            0
# 2  1936        49.0        45.0                  4.0            0
# 3  1936        49.0        44.0                  5.0            0
# 4  1936        49.0        45.0                  4.0            0
# 5  1936        50.0        44.0                  6.0            0
# 6  1936        51.0        44.0                  7.0            0
# 7  1936        51.0        44.0                  7.0            0
# 8  1936        56.0        44.0                 12.0            0
#
#    Republican_Electoral  Democrat_Electoral  Republican_Popular  \
# 0                   8.0               523.0          16681862.0
# 1                   8.0               523.0          16681862.0
# 2                   8.0               523.0          16681862.0
# 3                   8.0               523.0          16681862.0
# 4                   8.0               523.0          16681862.0
# 5                   8.0               523.0          16681862.0
# 6                   8.0               523.0          16681862.0
# 7                   8.0               523.0          16681862.0
# 8                   8.0               523.0          16681862.0
#
#    Democrat_Popular  Total_Popular_Vote  Republican_Electoral_pct  \
# 0        27752648.0          45647699.0                      1.51
# 1        27752648.0          45647699.0                      1.51
# 2        27752648.0          45647699.0                      1.51
# 3        27752648.0          45647699.0                      1.51
# 4        27752648.0          45647699.0                      1.51
# 5        27752648.0          45647699.0                      1.51
# 6        27752648.0          45647699.0                      1.51
# 7        27752648.0          45647699.0                      1.51
# 8        27752648.0          45647699.0                      1.51
#
#    Democrat_Electoral_pct  Republican_Popular_pct  Democrat_Popular_pct  \
# 0                   98.49                   36.54                  60.8
# 1                   98.49                   36.54                  60.8
# 2                   98.49                   36.54                  60.8
# 3                   98.49                   36.54                  60.8
# 4                   98.49                   36.54                  60.8
# 5                   98.49                   36.54                  60.8
# 6                   98.49                   36.54                  60.8
# 7                   98.49                   36.54                  60.8
# 8                   98.49                   36.54                  60.8
#
#    Electoral_Leading_Margin  Popular_Leading_Margin
# 0                     96.98                   24.26
# 1                     96.98                   24.26
# 2                     96.98                   24.26
# 3                     96.98                   24.26
# 4                     96.98                   24.26
# 5                     96.98                   24.26
# 6                     96.98                   24.26
# 7                     96.98                   24.26
# 8                     96.98                   24.26

# %%
# add columns Poll_vs_Electoral_Margin_Diff	(poll leading - electoral leading)
# and Poll_vs_Popular_Margin_Diff (poll leading - popular leading)

combined_df['Poll_vs_Electoral_Margin_Diff'] = combined_df['Poll_Leading_Margin'] - combined_df['Electoral_Leading_Margin']
combined_df['Poll_vs_Popular_Margin_Diff'] = combined_df['Poll_Leading_Margin'] - combined_df['Popular_Leading_Margin']

combined_df.head(25)
# Out:
#    year  Democratic  Republican  Poll_Leading_Margin  Poll_Leader  \
# 0  1936        49.0        45.0                  4.0            0
# 1  1936        49.0        45.0                  4.0            0
# 2  1936        49.0        45.0                  4.0            0
# 3  1936        49.0        44.0                  5.0            0
# 4  1936        49.0        45.0                  4.0            0
# 5  1936        50.0        44.0                  6.0            0
# 6  1936        51.0        44.0                  7.0            0
# 7  1936        51.0        44.0                  7.0            0
# 8  1936        56.0        44.0                 12.0            0
#
#    Republican_Electoral  Democrat_Electoral  Republican_Popular  \
# 0                   8.0               523.0          16681862.0
# 1                   8.0               523.0          16681862.0
# 2                   8.0               523.0          16681862.0
# 3                   8.0               523.0          16681862.0
# 4                   8.0               523.0          16681862.0
# 5                   8.0               523.0          16681862.0
# 6                   8.0               523.0          16681862.0
# 7                   8.0               523.0          16681862.0
# 8                   8.0               523.0          16681862.0
#
#    Democrat_Popular  Total_Popular_Vote  Republican_Electoral_pct  \
# 0        27752648.0          45647699.0                      1.51
# 1        27752648.0          45647699.0                      1.51
# 2        27752648.0          45647699.0                      1.51
# 3        27752648.0          45647699.0                      1.51
# 4        27752648.0          45647699.0                      1.51
# 5        27752648.0          45647699.0                      1.51
# 6        27752648.0          45647699.0                      1.51
# 7        27752648.0          45647699.0                      1.51
# 8        27752648.0          45647699.0                      1.51
#
#    Democrat_Electoral_pct  Republican_Popular_pct  Democrat_Popular_pct  \
# 0                   98.49                   36.54                  60.8
# 1                   98.49                   36.54                  60.8
# 2                   98.49                   36.54                  60.8
# 3                   98.49                   36.54                  60.8
# 4                   98.49                   36.54                  60.8
# 5                   98.49                   36.54                  60.8
# 6                   98.49                   36.54                  60.8
# 7                   98.49                   36.54                  60.8
# 8                   98.49                   36.54                  60.8
#
#    Electoral_Leading_Margin  Popular_Leading_Margin  \
# 0                     96.98                   24.26
# 1                     96.98                   24.26
# 2                     96.98                   24.26
# 3                     96.98                   24.26
# 4                     96.98                   24.26
# 5                     96.98                   24.26
# 6                     96.98                   24.26
# 7                     96.98                   24.26
# 8                     96.98                   24.26
#
#    Poll_vs_Electoral_Margin_Diff  Poll_vs_Popular_Margin_Diff
# 0                         -92.98                       -20.26
# 1                         -92.98                       -20.26
# 2                         -92.98                       -20.26
# 3                         -91.98                       -19.26
# 4                         -92.98                       -20.26
# 5                         -90.98                       -18.26
# 6                         -89.98                       -17.26
# 7                         -89.98                       -17.26
# 8                         -84.98                       -12.26

# %%
combined_df.to_csv("1936_Poll_v_Actual_dataset_with_diffs.csv", index=False)

# %%
combined_df.columns
# Out:
# Index(['year', 'Democratic', 'Republican', 'Poll_Leading_Margin',
#        'Poll_Leader', 'Republican_Electoral', 'Democrat_Electoral',
#        'Republican_Popular', 'Democrat_Popular', 'Total_Popular_Vote',
#        'Republican_Electoral_pct', 'Democrat_Electoral_pct',
#        'Republican_Popular_pct', 'Democrat_Popular_pct',
#        'Electoral_Leading_Margin', 'Popular_Leading_Margin',
#        'Poll_vs_Electoral_Margin_Diff', 'Poll_vs_Popular_Margin_Diff'],
#       dtype='object')
